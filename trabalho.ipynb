# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import norm
import arviz as az
import pandas as pd
import pymc as pm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Besteiro-exe/trabalhoPP/refs/heads/master/StudentStressFactors(2).csv")
df
# Out:
#      sleep quality  headaches per week  academic performance  study load  \
# 0                3                   1                     3           4
# 1                4                   1                     2           3
# 2                2                   1                     2           1
# 3                3                   2                     3           2
# 4                2                   3                     1           5
# ..             ...                 ...                   ...         ...
# 515              3                   2                     4           2
# 516              2                   4                     3           2
# 517              2                   3                     5           1
# 518              3                   4                     3           5
# 519              5                   1                     5           5
#
#      extracurricular activities per week  stress levels
# ...
